# %% [raw]
# REGRESIÓN LINEAL

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sb
import statsmodels.api as sm

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, confusion_matrix
from sympy.solvers import solve
from sympy import Symbol
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
Datos = pd.read_csv('./Car details v3.csv')

# %%
Datos.head(50)
# Out:
#                                            name  year  selling_price  \
# 0                        Maruti Swift Dzire VDI  2014         450000
# 1                  Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                      Honda City 2017-2020 EXi  2006         158000
# 3                     Hyundai i20 Sportz Diesel  2010         225000
# 4                        Maruti Swift VXI BSIII  2007         130000
# 5                 Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# 6                  Maruti Wagon R LXI DUO BSIII  2007          96000
# 7                            Maruti 800 DX BSII  2001          45000
# 8                              Toyota Etios VXD  2011         350000
# 9          Ford Figo Diesel Celebration Edition  2013         200000
# 10              Renault Duster 110PS Diesel RxL  2014         500000
# 11                                Maruti Zen LX  2005          92000
# 12                       Maruti Swift Dzire VDi  2009         280000
# 13                         Maruti Swift 1.3 VXi  2007         200000
# 14                     Maruti Wagon R LXI Minor  2009         180000
# 15         Mahindra KUV 100 mFALCON G80 K8 5str  2016         400000
# 16                       Maruti Ertiga SHVS VDI  2016         778000
# 17                    Hyundai i20 1.4 CRDi Asta  2012         500000
# 18                               Maruti Alto LX  2002         150000
# 19          Hyundai i20 2015-2017 Asta 1.4 CRDi  2016         680000
# 20                 Mahindra Verito 1.5 D4 BSIII  2011         174000
# 21                         Honda WR-V i-DTEC VX  2017         950000
# 22                       Maruti Swift Dzire ZDI  2015         525000
# 23                               Maruti SX4 ZDI  2012         600000
# 24                      Tata Tigor 2017-2020 XZ  2018         500000
# 25                      Maruti Baleno Delta 1.2  2016         575000
# 26                          Maruti Alto 800 LXI  2017         275000
# 27            Chevrolet Enjoy TCDi LTZ 7 Seater  2013         300000
# 28                     Maruti Wagon R LXI Minor  2009         220000
# 29                  Maruti Omni E MPI STD BS IV  2018         254999
# 30              Maruti Vitara Brezza LDi Option  2017         670000
# 31                           Fiat Palio 1.2 ELX  2003          70000
# 32                    Maruti Omni 8 Seater BSIV  2012         150000
# 33               Hyundai i20 1.2 Asta Dual Tone  2018         730000
# 34                     Maruti Vitara Brezza LDi  2017         650000
# 35             Maruti Alto 800 CNG LXI Optional  2019         330000
# 36                   Maruti Alto K10 VXI Airbag  2019         366000
# 37             Hyundai Verna VTVT 1.6 SX Option  2019        1149000
# 38                                  Datsun GO D  2016         150000
# 39                 Tata Safari DICOR 2.2 LX 4x2  2011         425000
# 40                               Maruti 800 Std  2012         150000
# 41           Jeep Compass 1.4 Limited Plus BSIV  2019        2100000
# 42                         Honda City i VTEC VX  2018         925000
# 43                              Honda City V MT  2013         425000
# 44                    Maruti Swift Dzire VXi AT  2018         675000
# 45                     Maruti Vitara Brezza VDi  2018         819999
# 46                          Maruti Alto K10 VXI  2018         390000
# 47                       Toyota Fortuner 4x4 MT  2014        1500000
# 48  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2013         700000
# 49                   Mercedes-Benz B Class B180  2014        1450000
#
#     km_driven    fuel seller_type transmission         owner      mileage  \
# 0      145500  Diesel  Individual       Manual   First Owner    23.4 kmpl
# 1      120000  Diesel  Individual       Manual  Second Owner   21.14 kmpl
# 2      140000  Petrol  Individual       Manual   Third Owner    17.7 kmpl
# 3      127000  Diesel  Individual       Manual   First Owner    23.0 kmpl
# 4      120000  Petrol  Individual       Manual   First Owner    16.1 kmpl
#
248 CC      74 bhp            190Nm@ 2000rpm    5.0
# 1   1498 CC  103.52 bhp       250Nm@ 1500-2500rpm    5.0
# 2   1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)    5.0
# 3   1396 CC      90 bhp  22.4 kgm at 1750-2750rpm    5.0
# 4   1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)    5.0
# 5   1197 CC   81.86 bhp         113.75nm@ 4000rpm    5.0
# 6   1061 CC    57.5 bhp      7.8@ 4,500(kgm@ rpm)    5.0
# 7    796 CC      37 bhp             59Nm@ 2500rpm    4.0
# 8   1364 CC    67.1 bhp       170Nm@ 1800-2400rpm    5.0
# 9   1399 CC    68.1 bhp            160Nm@ 2000rpm    5.0
# 10  1461 CC  108.45 bhp            248Nm@ 2250rpm    5.0
# 11   993 CC      60 bhp             78Nm@ 4500rpm    5.0
# 12  1248 CC    73.9 bhp            190Nm@ 2000rpm    5.0
# 13      NaN         NaN                       NaN    NaN
# 14  1061 CC      67 bhp             84Nm@ 3500rpm    5.0
# 15  1198 CC      82 bhp       115Nm@ 3500-3600rpm    5.0
# 16  1248 CC    88.5 bhp            200Nm@ 1750rpm    7.0
# 17  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm    5.0
# 18   796 CC    46.3 bhp             62Nm@ 3000rpm    5.0
# 19  1396 CC   88.73 bhp     219.7Nm@ 1500-2750rpm    5.0
# 20  1461 CC    64.1 bhp            160Nm@ 2000rpm    5.0
# 21  1498 CC    98.6 bhp            200Nm@ 1750rpm    5.0
# 22  1248 CC      74 bhp            190Nm@ 2000rpm    5.0
# 23  1248 CC    88.8 bhp            200Nm@ 1750rpm    5.0
# 24  1199 CC   83.81 bhp            114Nm@ 3500rpm    5.0
# 25  1197 CC    83.1 bhp            115Nm@ 4000rpm    5.0
# 26   796 CC    47.3 bhp             69Nm@ 3500rpm    5.0
# 27  1248 CC    73.8 bhp          172.5Nm@ 1750rpm    7.0
# 28  1061 CC      67 bhp             84Nm@ 3500rpm    5.0
# 29   796 CC    34.2 bhp             59Nm@ 2500rpm    8.0
# 30  1248 CC    88.5 bhp            200Nm@ 1750rpm    5.0
# 31      NaN         NaN                       NaN    NaN
# 32   796 CC      35 bhp           6.1kgm@ 3000rpm    5.0
# 33  1197 CC   81.83 bhp          114.7Nm@ 4000rpm    5.0
# 34  1248 CC    88.5 bhp            200Nm@ 1750rpm    5.0
# 35   796 CC    40.3 bhp             60Nm@ 3500rpm    4.0
# 36   998 CC    67.1 bhp             90Nm@ 3500rpm    5.0
# 37  1591 CC   121.3 bhp            151Nm@ 4850rpm    5.0
# 38  1198 CC      67 bhp            104Nm@ 4000rpm    5.0
# 39  2179 CC  138.03 bhp       320Nm@ 1700-2700rpm    7.0
# 40   796 CC      37 bhp             59Nm@ 2500rpm    4.0
# 41  1368 CC  160.77 bhp       250Nm@ 1750-2500rpm    5.0
# 42  1497 CC   117.3 bhp            145Nm@ 4600rpm    5.0
# 43  1497 CC   116.3 bhp            146Nm@ 4800rpm    5.0
# 44  1197 CC   83.14 bhp            115Nm@ 4000rpm    5.0
# 45  1248 CC    88.5 bhp            200Nm@ 1750rpm    5.0
# 46   998 CC   67.05 bhp             90Nm@ 3500rpm    5.0
# 47  2982 CC   168.5 bhp       343Nm@ 1400-3400rpm    7.0
# 48  2494 CC     100 bhp       200Nm@ 1400-3400rpm    7.0
# 49  2143 CC   120.7 bhp       200Nm@ 1250-4000rpm    5.0

# %%
Datos.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['year'])
plt.title('Idenficación de Datos faltas y atípicos', fontsize=9)
# Out:
# Text(0.5, 1.0, 'Idenficación de Datos faltas y atípicos')

# %%
print("Cantidad de registros con cero en nombre: ",Datos['name'].isnull().sum())
print("Cantidad de registros con cero en año: ",Datos['year'].isnull().sum())
print("Cantidad de registros con cero en precio de venta: ",Datos['selling_price'].isnull().sum())
print("Cantidad de registros con cero en km impulsado: ",Datos['km_driven'].isnull().sum())
print("Cantidad de registros con cero en combustible: ",Datos['fuel'].isnull().sum())
print("Cantidad de registros con cero en tipo vendedor: ",Datos['seller_type'].isnull().sum())
print("Cantidad de registros con cero en transmisión: ",Datos['transmission'].isnull().sum())
print("Cantidad de registros con cero en dueño: ",Datos['owner'].isnull().sum())
print("Cantidad de registros con cero en kilometraje: ",Datos['mileage'].isnull().sum())
print("Cantidad de registros con cero en motor: ",Datos['engine'].isnull().sum())
print("Cantidad de registros con cero en máximo poder: ",Datos['max_power'].isnull().sum())
print("Cantidad de registros con cero en esfuerzo de torsión: ",Datos['torque'].isnull().sum())
print("Cantidad de registros con cero en asientos: ",Datos['seats'].isnull().sum())
# Out:
# Cantidad de registros con cero en nombre:  0
# Cantidad de registros con cero en año:  0
# Cantidad de registros con cero en precio de venta:  0
# Cantidad de registros con cero en km impulsado:  0
# Cantidad de registros con cero en combustible:  0
# Cantidad de registros con cero en tipo vendedor:  0
# Cantidad de registros con cero en transmisión:  0
# Cantidad de registros con cero en dueño:  0
# Cantidad de registros con cero en kilometraje:  221
# Cantidad de registros con cero en motor:  221
# Cantidad de registros con cero en máximo poder:  215
# Cantidad de registros con cero en esfuerzo de torsión:  222
# Cantidad de registros con cero en asientos:  221

# %%
Datos['mileage'].fillna(0, inplace = True)
Datos['engine'].fillna(0, inplace = True)
Datos['max_power'].fillna(0, inplace = True)
Datos['torque'].fillna(0, inplace = True)
Datos['seats'].fillna(0, inplace = True)

# %%
Datos.head(50)
# Out:
#                                            name  year  selling_price  \
# 0                        Maruti Swift Dzire VDI  2014         450000
# 1                  Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                      Honda City 2017-2020 EXi  2006         158000
# 3                     Hyundai i20 Sportz Diesel  2010         225000
# 4                        Maruti Swift VXI BSIII  2007         130000
# 5                 Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# 6                  Maruti Wagon R LXI DUO BSIII  2007          96000
# 7                            Maruti 800 DX BSII  2001          45000
# 8                              Toyota Etios VXD  2011         350000
# 9          Ford Figo Diesel Celebration Edition  2013         200000
# 10              Renault Duster 110PS Diesel RxL  2014         500000
# 11                                Maruti Zen LX  2005          92000
# 12                       Maruti Swift Dzire VDi  2009         280000
# 13                         Maruti Swift 1.3 VXi  2007         200000
# 14                     Maruti Wagon R LXI Minor  2009         180000
# 15         Mahindra KUV 100 mFALCON G80 K8 5str  2016         400
1396 CC      90 bhp  22.4 kgm at 1750-2750rpm    5.0
# 18   796 CC    46.3 bhp             62Nm@ 3000rpm    5.0
# 19  1396 CC   88.73 bhp     219.7Nm@ 1500-2750rpm    5.0
# 20  1461 CC    64.1 bhp            160Nm@ 2000rpm    5.0
# 21  1498 CC    98.6 bhp            200Nm@ 1750rpm    5.0
# 22  1248 CC      74 bhp            190Nm@ 2000rpm    5.0
# 23  1248 CC    88.8 bhp            200Nm@ 1750rpm    5.0
# 24  1199 CC   83.81 bhp            114Nm@ 3500rpm    5.0
# 25  1197 CC    83.1 bhp            115Nm@ 4000rpm    5.0
# 26   796 CC    47.3 bhp             69Nm@ 3500rpm    5.0
# 27  1248 CC    73.8 bhp          172.5Nm@ 1750rpm    7.0
# 28  1061 CC      67 bhp             84Nm@ 3500rpm    5.0
# 29   796 CC    34.2 bhp             59Nm@ 2500rpm    8.0
# 30  1248 CC    88.5 bhp            200Nm@ 1750rpm    5.0
# 31        0           0                         0    0.0
# 32   796 CC      35 bhp           6.1kgm@ 3000rpm    5.0
# 33  1197 CC   81.83 bhp          114.7Nm@ 4000rpm    5.0
# 34  1248 CC    88.5 bhp            200Nm@ 1750rpm    5.0
# 35   796 CC    40.3 bhp             60Nm@ 3500rpm    4.0
# 36   998 CC    67.1 bhp             90Nm@ 3500rpm    5.0
# 37  1591 CC   121.3 bhp            151Nm@ 4850rpm    5.0
# 38  1198 CC      67 bhp            104Nm@ 4000rpm    5.0
# 39  2179 CC  138.03 bhp       320Nm@ 1700-2700rpm    7.0
# 40   796 CC      37 bhp             59Nm@ 2500rpm    4.0
# 41  1368 CC  160.77 bhp       250Nm@ 1750-2500rpm    5.0
# 42  1497 CC   117.3 bhp            145Nm@ 4600rpm    5.0
# 43  1497 CC   116.3 bhp            146Nm@ 4800rpm    5.0
# 44  1197 CC   83.14 bhp            115Nm@ 4000rpm    5.0
# 45  1248 CC    88.5 bhp            200Nm@ 1750rpm    5.0
# 46   998 CC   67.05 bhp             90Nm@ 3500rpm    5.0
# 47  2982 CC   168.5 bhp       343Nm@ 1400-3400rpm    7.0
# 48  2494 CC     100 bhp       200Nm@ 1400-3400rpm    7.0
# 49  2143 CC   120.7 bhp       200Nm@ 1250-4000rpm    5.0

# %%
print("Cantidad de registros con cero en nombre: ",Datos['name'].isnull().sum())
print("Cantidad de registros con cero en año: ",Datos['year'].isnull().sum())
print("Cantidad de registros con cero en precio de venta: ",Datos['selling_price'].isnull().sum())
print("Cantidad de registros con cero en km impulsado: ",Datos['km_driven'].isnull().sum())
print("Cantidad de registros con cero en combustible: ",Datos['fuel'].isnull().sum())
print("Cantidad de registros con cero en tipo vendedor: ",Datos['seller_type'].isnull().sum())
print("Cantidad de registros con cero en transmisión: ",Datos['transmission'].isnull().sum())
print("Cantidad de registros con cero en dueño: ",Datos['owner'].isnull().sum())
print("Cantidad de registros con cero en kilometraje: ",Datos['mileage'].isnull().sum())
print("Cantidad de registros con cero en motor: ",Datos['engine'].isnull().sum())
print("Cantidad de registros con cero en máximo poder: ",Datos['max_power'].isnull().sum())
print("Cantidad de registros con cero en esfuerzo de torsión: ",Datos['torque'].isnull().sum())
print("Cantidad de registros con cero en asientos: ",Datos['seats'].isnull().sum())
# Out:
# Cantidad de registros con cero en nombre:  0
# Cantidad de registros con cero en año:  0
# Cantidad de registros con cero en precio de venta:  0
# Cantidad de registros con cero en km impulsado:  0
# Cantidad de registros con cero en combustible:  0
# Cantidad de registros con cero en tipo vendedor:  0
# Cantidad de registros con cero en transmisión:  0
# Cantidad de registros con cero en dueño:  0
# Cantidad de registros con cero en kilometraje:  0
# Cantidad de registros con cero en motor:  0
# Cantidad de registros con cero en máximo poder:  0
# Cantidad de registros con cero en esfuerzo de torsión:  0
# Cantidad de registros con cero en asientos:  0

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['year'])
plt.title('Idenficación de Datos faltas y atípicos', fontsize=9)
# Out:
# Text(0.5, 1.0, 'Idenficación de Datos faltas y atípicos')

# %%
nivel_minimo=1900
nivel_maximo=2000
Total_atipicos=((Datos['year']<nivel_minimo)|(Datos['year']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_atipicos))
# Out:
# El total de datos atípicos es 0

# %%
Datos = Datos[(Datos['year']<nivel_maximo)&(Datos['year']>nivel_minimo)]

# %%
Total_atipicos=((Datos['year']<nivel_minimo)|(Datos['year']>nivel_maximo)).sum()
print ("El total de datos atípicos es {}".format(Total_atipicos))
# Out:
# El total de datos atípicos es 0

# %%
Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 177 to 8115
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           49 non-null     object
#  1   year           49 non-null     int64
#  2   selling_price  49 non-null     int64
#  3   km_driven      49 non-null     int64
#  4   fuel           49 non-null     object
#  5   seller_type    49 non-null     object
#  6   transmission   49 non-null     object
#  7   owner          49 non-null     object
#  8   mileage        49 non-null     object
#  9   engine         49 non-null     object
#  10  max_power      49 non-null     object
#  11  torque         49 non-null     object
#  12  seats          49 non-null     float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 5.4+ KB

# %%
Datos['selling_price'].value_counts()
# Out:
# selling_price
# 40000     6
# 70000     6
# 80000     4
# 55000     4
# 50000     4
# 45000     3
# 160000    2
# 60000     2
# 300000    2
# 150000    2
# 99000     1
# 58000     1
# 42000     1
# 57000     1
# 125000    1
# 29999     1
# 210000    1
# 68000     1
# 155000    1
# 78000     1
# 52000     1
# 120000    1
# 163000    1
# 35000     1
# Name: count, dtype: int64

# %%
Datos = Datos[['selling_price', 'km_driven', 'seats', 'year']]

# %%
X = Datos.drop('selling_price',axis=1)
Y = Datos['selling_price']

# %%
X.head(50)
# Out:
#                                    name  year  km_driven    fuel seller_type  \
# 177                      Maruti 800 Std  1999      40000  Petrol  Individual
# 316           Mahindra Willys CJ 3B 4X4  1983      10000  Diesel  Individual
# 774       Hyundai Santro GLS I - Euro I  1999     110000  Petrol  Individual
# 999                       Maruti 800 AC  1999      60000  Petrol  Individual
# 1216              Mahindra Jeep Classic  1996       5000  Diesel  Individual
# 1432           Mahindra Jeep CL 500 MDI  1994     100000  Diesel  Individual
# 1468                      Maruti 800 DX  1999     100000  Petrol  Individual
Manual           First Owner  16.1 kmpl   796 CC    37 bhp
# 1815       Manual           Third Owner        123        0         0
# 2327       Manual           First Owner  14.0 kmpl   796 CC    35 bhp
# 2340       Manual  Fourth & Above Owner  17.3 kmpl   993 CC    60 bhp
# 2424       Manual           Third Owner  16.1 kmpl   796 CC    37 bhp
# 3046       Manual  Fourth & Above Owner  16.1 kmpl   796 CC    37 bhp
# 3097       Manual           Third Owner        123        0         0
# 3310       Manual           Third Owner        123        0         0
# 3890       Manual           First Owner  16.1 kmpl   796 CC    37 bhp
# 3922       Manual          Second Owner        123        0         0
# 4108       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 4253       Manual           Third Owner  14.8 kmpl  1998 CC    68 bhp
# 4285       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 4372       Manual           Third Owner  13.1 kmpl  1598 CC    77 bhp
# 4542       Manual  Fourth & Above Owner        123        0         0
# 4712       Manual          Second Owner  12.8 kmpl  1995 CC    52 bhp
# 5080       Manual           Third Owner  16.1 kmpl   796 CC    37 bhp
# 5322       Manual          Second Owner        123        0         0
# 5349       Manual          Second Owner  14.8 kmpl  1998 CC    68 bhp
# 5385       Manual  Fourth & Above Owner        123        0         0
# 5411       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 5610       Manual          Second Owner  17.3 kmpl   993 CC    60 bhp
# 5702       Manual          Second Owner  17.3 kmpl   993 CC    60 bhp
# 5714       Manual           Third Owner  16.1 kmpl   796 CC    37 bhp
# 5726    Automatic  Fourth & Above Owner  15.9 kmpl  1298 CC    85 bhp
# 6164       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 6320       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 6387       Manual           Third Owner  17.3 kmpl   993 CC    60 bhp
# 6436       Manual          Second Owner  17.3 kmpl   993 CC    60 bhp
# 6521       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 6639       Manual           First Owner  16.1 kmpl   796 CC    37 bhp
# 6730       Manual           Third Owner        123        0         0
# 6919       Manual  Fourth & Above Owner  15.9 kmpl  1298 CC    85 bhp
# 6920       Manual  Fourth & Above Owner  15.9 kmpl  1298 CC    85 bhp
# 6933       Manual           Third Owner  16.1 kmpl   796 CC    37 bhp
# 7218       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 7471       Manual          Second Owner  14.8 kmpl  1998 CC    68 bhp
# 7765       Manual           Third Owner  17.3 kmpl   993 CC    60 bhp
# 7935       Manual           Third Owner  16.1 kmpl   796 CC    37 bhp
# 8025       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 8042       Manual          Second Owner  14.8 kmpl  1298 CC    80 bhp
# 8115       Manual           First Owner  16.1 kmpl   796 CC    37 bhp
#
#                      torque  seats
# 177           59Nm@ 2500rpm    4.0
# 316                       0    0.0
# 774                       0    0.0
# 999           59Nm@ 2500rpm    4.0
# 1216                      0    0.0
# 1432                      0    0.0
# 1468          59Nm@ 2500rpm    4.0
# 1474          59Nm@ 2500rpm    4.0
# 1815                      0    0.0
# 2327        6.1kgm@ 3000rpm    5.0
# 2340          78Nm@ 4500rpm    5.0
# 2424          59Nm@ 2500rpm    4.0
# 3046          59Nm@ 2500rpm    4.0
# 3097                      0    0.0
# 3310                      0    0.0
# 3890          59Nm@ 2500rpm    4.0
# 3922                      0    0.0
# 4108          59Nm@ 2500rpm    4.0
# 4253  12.5@ 3,000(kgm@ rpm)    5.0
# 4285          59Nm@ 2500rpm    4.0
# 4372         121Nm@ 2800rpm    5.0
# 4542                      0    0.0
# 4712         106Nm@ 2200rpm    5.0
# 5080          59Nm@ 2500rpm    4.0
# 5322                      0    0.0
# 5349  12.5@ 3,000(kgm@ rpm)    5.0
# 5385                      0    0.0
# 5411          59Nm@ 2500rpm    4.0
# 5610          78Nm@ 4500rpm    5.0
# 5702          78Nm@ 4500rpm    5.0
# 5714          59Nm@ 2500rpm    4.0
# 5726         110Nm@ 4500rpm    5.0
# 6164          59Nm@ 2500rpm    4.0
# 6320          59Nm@ 2500rpm    4.0
# 6387          78Nm@ 4500rpm    5.0
# 6436          78Nm@ 4500rpm    5.0
# 6521          59Nm@ 2500rpm    4.0
# 6639          59Nm@ 2500rpm    4.0
# 6730                      0    0.0
# 6919         110Nm@ 4500rpm    5.0
# 6920         110Nm@ 4500rpm    5.0
# 6933          59Nm@ 2500rpm    4.0
# 7218          59Nm@ 2500rpm    4.0
# 7471  12.5@ 3,000(kgm@ rpm)    5.0
# 7765          78Nm@ 4500rpm    5.0
# 7935          59Nm@ 2500rpm    4.0
# 8025          59Nm@ 2500rpm    4.0
# 8042         103Nm@ 4500rpm    8.0
# 8115          59Nm@ 2500rpm    4.0

# %%
Y.head(50)
# Out:
# 177      40000
# 316     300000
# 774      80000
# 999      55000
# 1216    163000
# 1432    120000
# 1468     52000
# 1474     45000
# 1815    160000
# 2327     80000
# 2340     50000
# 2424     60000
# 3046     45000
# 3097     60000
# 3310     78000
# 3890     55000
# 3922    210000
# 4108     40000
# 4253    155000
# 4285     70000
# 4372     68000
# 4542     70000
# 4712     99000
# 5080     80000
# 5322     55000
# 5349    150000
# 5385    160000
# 5411     50000
# 5610     70000
# 5702     70000
# 5714     29999
# 5726    125000
# 6164     50000
# 6320     40000
# 6387     45000
# 6436     55000
# 6521     40000
# 6639     80000
# 6730     57000
# 6919     70000
# 6920     70000
# 6933     42000
# 7218     50000
# 7471    150000
# 7765     58000
# 7935     40000
# 8025     35000
# 8042    300000
# 8115     40000
# Name: selling_price, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state= 0)

# %%
print (X_train)
# Out:
#                                    name  year  km_driven    fuel seller_type  \
# 5411                     Maruti 800 Std  1997     110000  Petrol  Individual
# 8115                      Maruti 800 AC  1997     120000  Petrol  Individual
# 774       Hyundai Santro GLS I - Euro I  1999     110000  Petrol  Individual
# 8025                      Maruti 800 AC  1998      40000  Petrol  Individual
# 4253          Mitsubishi Lancer 2.0 LXd  1999     100000  Diesel  Individual
# 3890                     Maruti 800 Std  1995      70000  Petrol  Individual
# 5610                 Maruti Zen LX BSII  1998      40000  Petrol  Individual
# 4712  Ambassador Classic 2000 DSZ AC PS  1994     100000  Diesel  Individual
# 3922               Mahindra Jeep MM 540  1998      47990  Diesel  Individual
# 6933                      Maruti 800 AC  1996      70000  Petrol  Individual
# 4372                     Opel Astra 1.6  1998     110000  Petrol  Individual
# 7218                      Maruti 800 AC  1997      60000  Petrol  Individual
# 1815               Mahindra Jeep MM 540  1995      90000  Diesel  Individual
# 3097      Hyundai Santro GLS I - Euro I  1999     140000  Petrol  Individual
# 5349          Mitsubishi Lancer 2.0 GLd  1999     198000  Diesel  Individual
# 1432           Mahindra Jeep CL 500 MDI  1994     100000  Diesel  Individual
# 4108                      Maruti 800 DX  1996      32000  Petrol  Individual
# 6436                     Maruti Zen VXI  1998      50000  Petrol  Individual
# 3310                    Tata Estate Std  1999      80000  Diesel  Individual
# 6730                    Peugeot 309 GLD  1997     110000  Diesel  Individual
# 316           Mahindra Willys CJ 3B 4X4  1983      10000  Diesel  Individual
# 3046                      Maruti 800 DX  1998      80000  Petrol  Individual
# 7471          Mitsubishi Lancer 2.0 GLd  1999     198000  Diesel  Individual
# 5322           Maruti Omni LPG STD BSIV  1991     120000     LPG  Individual
# 1468                      Maruti 800 DX  1999     100000  Petrol  Individual
# 5080                      Maruti 800 AC  1999      80000  Petrol  Individual
# 6521                      Maruti 800 DX  1999      50000  Petrol  Individual
# 4542           Maruti Omni LPG STD BSIV  1999     100000     LPG  Individual
# 4285                      Maruti 800 DX  1998     100000  Petrol  Individual
# 2327              Maruti Omni 5 Str STD  1998      70000  Petrol  Individual
# 6919           Maruti Esteem LX - BSIII  1999      65000  Petrol  Individual
# 7935                      Maruti 800 AC  1999     100000  Petrol  Individual
# 999                       Maruti 800 AC  1999      60000  Petrol  Individual
# 177                      Maruti 800 Std  1999      40000  Petrol  Individual
# 8042         Maruti Gypsy King Soft Top  1997     186388  Petrol  Individual
# 7765                 Maruti Zen Classic  1998      80000  Petrol  Individual
#
#      transmission                 owner    mileage   engine max_power  \
# 5411       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 8115       Manual           First Owner  16.1 kmpl   796 CC    37 bhp
# 774        Manual          Second Owner        123        0         0
# 8025       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 4253       Manual           Third Owner  14.8 kmpl  1998 CC    68 bhp
# 3890       Manual           First Owner  16.1 kmpl   796 CC    37 bhp
# 5610       Manual          Second Owner  17.3 kmpl   993 CC    60 bhp
# 4712       Manual          Second Owner  12.8 kmpl  1995 CC    52 bhp
# 3922       Manual          Second Owner        123        0         0
# 6933       Manual           Third Owner  16.1 kmpl   796 CC    37 bhp
# 4372       Manual           Third Owner  13.1 kmpl  1598 CC    77 bhp
# 7218       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 1815       Manual           Third Owner        123        0         0
# 3097       Manual           Third Owner        123        0         0
# 5349       Manual          Second Owner  14.8 kmpl  1998 CC    68 bhp
# 1432       Manual          Second Owner        123        0         0
# 4108       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 6436       Manual          Second Owner  17.3 kmpl   993 CC    60 bhp
# 3310       Manual           Third Owner        123        0         0
# 6730       Manual           Third Owner        123        0         0
# 316        Manual           Third Owner        123        0         0
# 3046       Manual  Fourth & Above Owner  16.1 kmpl   796 CC    37 bhp
# 7471       Manual          Second Owner  14.8 kmpl  1998 CC    68 bhp
# 5322       Manual          Second Owner        123        0         0
# 1468       Manual           First Owner  16.1 kmpl   796 CC    37 bhp
# 5080       Manual           Third Owner  16.1 kmpl   796 CC    37 bhp
# 6521       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 4542       Manual  Fourth & Above Owner        123        0         0
# 4285       Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 2327       Manual           First Owner  14.0 kmpl   796 CC    35 bhp
# 6919       Manual  Fourth & Above Owner  15.9 kmpl  1298 CC    85 bhp
# 7935       Manual           Third Owner  16.1 kmpl   796 CC    37 bhp
# 999        Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 177        Manual          Second Owner  16.1 kmpl   796 CC    37 bhp
# 8042       Manual          Second Owner  14.8 kmpl  1298 CC    80 bhp
# 7765       Manual           Third Owner  17.3 kmpl   993 CC    60 bhp
#
#                      torque  seats
# 5411          59Nm@ 2500rpm    4.0
# 8115          59Nm@ 2500rpm    4.0
# 774                       0    0.0
# 8025          59Nm@ 2500rpm    4.0
# 4253  12.5@ 3,000(kgm@ rpm)    5.0
# 3890          59Nm@ 2500rpm    4.0
# 5610          78Nm@ 4500rpm    5.0
# 4712         106Nm@ 2200rpm    5.0
# 3922                      0    0.0
# 6933          59Nm@ 2500rpm    4.0
# 4372         121Nm@ 2800rpm    5.0
# 7218          59Nm@ 2500rpm    4.0
# 1815                      0    0.0
# 3097                      0    0.0
# 5349  12.5@ 3,000(kgm@ rpm)    5.0
# 1432                      0    0.0
# 4108          59Nm@ 2500rpm    4.0
# 6436          78Nm@ 4500rpm    5.0
# 3310                      0    0.0
# 6730                      0    0.0
# 316                       0    0.0
# 3046          59Nm@ 2500rpm    4.0
# 7471  12.5@ 3,000(kgm@ rpm)    5.0
# 5322                      0    0.0
# 1468          59Nm@ 2500rpm    4.0
# 5080          59Nm@ 2500rpm    4.0
# 6521          59Nm@ 2500rpm    4.0
# 4542                      0    0.0
# 4285          59Nm@ 2500rpm    4.0
# 2327        6.1kgm@ 3000rpm    5.0
# 6919         110Nm@ 4500rpm    5.0
# 7935          59Nm@ 2500rpm    4.0
# 999           59Nm@ 2500rpm    4.0
# 177           59Nm@ 2500rpm    4.0
# 8042         103Nm@ 4500rpm    8.0
# 7765          78Nm@ 4500rpm    5.0

# %%
print (Y_train)
# Out:
# 5411     50000
# 8115     40000
# 774      80000
# 8025     35000
# 4253    155000
# 3890     55000
# 5610     70000
# 4712     99000
# 3922    210000
# 6933     42000
# 4372     68000
# 7218     50000
# 1815    160000
# 3097     60000
# 5349    150000
# 1432    120000
# 4108     40000
# 6436     55000
# 3310     78000
# 6730     57000
# 316     300000
# 3046     45000
# 7471    150000
# 5322     55000
# 1468     52000
# 5080     80000
# 6521     40000
# 4542     70000
# 4285     70000
# 2327     80000
# 6919     70000
# 7935     40000
# 999      55000
# 177      40000
# 8042    300000
# 7765     58000
# Name: selling_price, dtype: int64

# %%
modelo_regresion = LinearRegression()
modelo_regresion.fit (X_train , Y_train)

Prediccion = modelo_regresion.predict(X_test)

# %%
print (Y_test)
# Out:
# 5702     70000
# 1216    163000
# 5385    160000
# 5714     29999
# 6164     50000
# 6639     80000
# 6387     45000
# 6920     70000
# 1474     45000
# 2340     50000
# 2424     60000
# 5726    125000
# 6320     40000
# Name: selling_price, dtype: int64

# %%
print (Prediccion)
# Out:
# [100061.61710075  48035.50066618  87907.48954931  86626.71337407
#  108634.86980686  32297.00215182  75266.85181129  58760.7344867
#  112814.78309188  53258.69537851  56365.498279    96760.39363584
#   68727.29162115]

# %%
from sklearn import metrics
print('El error absoluto medio del modelo es:', metrics.mean_absolute_error(Y_test, Prediccion))
print('El Error Cuadrático Medio del modelo es:', metrics.mean_squared_error(Y_test, Prediccion))
print('El error cuadratico medio del modelo es:', np.sqrt(metrics.mean_squared_error(Y_test, Prediccion)))
# Out:
# El error absoluto medio del modelo es: 42558.86180120506
# El Error Cuadrático Medio del modelo es: 2732769110.7139025
# El error cuadratico medio del modelo es: 52275.894164652054

# %%
fig = plt.figure()
plt.scatter(Y_test, Prediccion)
fig.suptitle('Y_test VS Prediccion', fontsize=20)
plt.xlabel('Y_test', fontsize=18)
plt.ylabel('Prediccion', fontsize=16)
# Out:
# Text(0, 0.5, 'Prediccion')
